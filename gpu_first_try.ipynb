# %%
from ppafm.io import loadXYZ
from ppafm.ocl.AFMulator import AFMulator
from ppafm.ocl.oclUtils import init_env

# %%
# Initialize an OpenCL environment. You can change i_platform to select the device to use.
init_env(i_platform=0)
# Out:
# Initializing an OpenCL environment on NVIDIA CUDA

# %%
# Load sample coordinates (xyzs), atomic numbers (Zs), and charges (qs)
xyzs, Zs, qs, _ = loadXYZ("materials/pt_111_small_1_3_vacancies.xyz")

# Create an instance of the simulator
# afmulator = AFMulator(
#     # scan_dim=(201, 201, 51),
#     # scan_window=((45.0, 25.0, 16), (60.0, 50.0, 19)),
#     df_steps=1,
#     # iZPP=8,
#     # tipR0=[0.0, 0.0, 3.0]
# )
afmulator = AFMulator.from_params("materials/params_code.ini")
# df_steps is calculated by dividing amplitude by scanStep in z dir
# afmulator.setScanWindow(df_steps=20)
# Out:
# sigma:  0.7
# Spherical harmonic: s

# %%
# Run the simulation and plot the resulting images
afm_images = afmulator(xyzs, Zs, qs, plot_to_dir="output")
# Out:
# sigma:  0.7
# Spherical harmonic: s
#  plotting slice # 250

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] =  [10, 10]

def plot_surface(img, vmin=None, vmax=None):
    plt.imshow(img[:,::-1].T, vmin=vmin, vmax=vmax)
    
plot_surface(afm_images[:,:,188])
plt.scatter(14, 32)

# %%
import numpy as np
z = np.linspace(
            afmulator.scan_window[0][2],
            afmulator.scan_window[1][2] - afmulator.df_steps * afmulator.dz,
            afmulator.scan_dim[2] - afmulator.df_steps + 1,
        )

# %%
x, y = 14, 32
#plt.plot(z, afm_images[14, 32, :])
plt.plot(z, afm_images[x, y, :])
plt.scatter(z[np.argmin(afm_images, axis=2)[x, y]], afm_images[x,y, np.argmin(afm_images, axis=2)[x, y]])

#plt.xlim(18.5, 19.5)
#plt.ylim(-3.3, -2)

# %%
from scipy.ndimage import gaussian_filter

plt.rcParams["figure.figsize"] =  [20, 10]

min_image = np.argmin(afm_images, axis=2)
blurred_image = gaussian_filter(min_image, sigma=6)
vmin = np.min(min_image)
vmax = np.max(min_image)

plt.subplots(1, 2)

plt.subplot(1, 2, 1)
plt.title(f"Unique indices: {np.unique(min_image)}")
plot_surface(min_image, vmin=vmin, vmax=vmax)
plt.scatter(21, 32)

plt.subplot(1, 2, 2)
plt.title(f"Unique indices: {np.unique(blurred_image)}")
plot_surface(blurred_image, vmin=vmin, vmax=vmax)

# %%
x, y = 21, 32
print(np.median(np.argmin(afm_images, axis=2)))
print(afm_images[x, y, 188])
print(np.argmin(afm_images, axis=2)[x, y])
z[np.argmin(afm_images, axis=2)[x, y]]
# Out:
# 188.0
# -2.9196672
# 186
# 18.72

# %%
unique_vals = np.unique(np.argmin(afm_images, axis=2))
print(z[unique_vals[0]], z[unique_vals[-1]])
# Out:
# 18.66 19.86

# %%
from ppafm.io import loadXYZ
from ppafm.ocl.AFMulator import AFMulator
from ppafm.ocl.oclUtils import init_env
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from scipy.signal import argrelmin
import numpy as np

def plot_surface(img, vmin=None, vmax=None):
    plt.imshow(img.T, vmin=vmin, vmax=vmax)
    
def compute_imgs(path_surface):
    init_env(i_platform=0)
    xyzs, Zs, qs, _ = loadXYZ(path_surface)
    afmulator = AFMulator.from_params("materials/params_code.ini")
    afm_images = afmulator(xyzs, Zs, qs)#, plot_to_dir="output")
    
    return afmulator, afm_images
    
    
def argmin_surface_and_blur(afmulator, afm_images, xy=(32, 14)):
    # if compute_img:
    # init_env(i_platform=0)
    # xyzs, Zs, qs, _ = loadXYZ(path_surface)
    # afmulator = AFMulator.from_params("materials/params_code.ini")
    # afm_images = afmulator(xyzs, Zs, qs, plot_to_dir="output")[:,:,::-1]
    
    xy = np.array(xy)
    
    z = np.linspace(
                afmulator.scan_window[0][2],
                afmulator.scan_window[1][2] - afmulator.df_steps * afmulator.dz,
                afmulator.scan_dim[2] - afmulator.df_steps + 1,
    )
    
    plt.rcParams["figure.figsize"] =  [20, 10]
    
    afm_images_transformed = afm_images[:,::-1,::-1]
    
    min_image = z[np.argmin(afm_images_transformed, axis=2)]
    blurred_image = gaussian_filter(min_image, sigma=6)
    vmin = np.min(min_image)
    vmax = np.max(min_image)
    
    plt.subplots(1, 2)
    
    plt.subplot(1, 2, 1)
    plt.title(f"Unique indices: {np.unique(min_image)}")
    plot_surface(min_image, vmin=vmin, vmax=vmax)
    plt.colorbar()
    plt.scatter(xy[0], xy[1], color='red')
    plt.tight_layout()
    
    plt.subplot(1, 2, 2)
    plt.title(f"Unique indices: {np.unique(blurred_image)}")
    plot_surface(blurred_image, vmin=vmin, vmax=vmax)
    plt.colorbar()
    plt.scatter(xy[0], xy[1], color='red')
    plt.tight_layout()
    
    plt.show()
    
    print(afm_images_transformed[xy[0], xy[1]])
    minima = argrelmin(afm_images_transformed[xy[0], xy[1]])
    print(minima)
    
    plt.plot(z, afm_images_transformed[xy[0], xy[1], :])
    #plt.scatter(z[np.argmin(afm_images_transformed, axis=2)[xy[0], xy[1]]], afm_images_transformed[xy[0],xy[1], np.argmin(afm_images_transformed, axis=2)[xy[0], xy[1]]])
    for minimum in minima:
        plt.scatter(z[minimum], afm_images_transformed[xy[0], xy[1], minimum])
    
    plt.show()

# %%
afmulator, afm_images = compute_imgs("materials/pt_111_small_rows_missing.xyz")
# Out:
# Initializing an OpenCL environment on NVIDIA CUDA
# sigma:  0.7
# Spherical harmonic: s
# sigma:  0.7
# Spherical harmonic: s

# %%
# pt_111_smal_1_3_vacancies.xyz
xy_3_vacancy = (118, 69)
xy_1_vacancy = (21, 25)

# pt_111_small_rows_missing.xyz
xy_2row_corner = (103, 67)
xy_3row_corner = (146, 67)
xy_3row_middle = (171, 44)
xy_reference = (77, 67)

xy_test = (162, 44)

argmin_surface_and_blur(afmulator, afm_images, xy=xy_reference)
# Out:
# [-2.0973094  -2.1009889  -2.1055698  -2.1162899  -2.1278133  -2.1425536
#  -2.1541953  -2.1632543  -2.1767297  -2.1906445  -2.207058   -2.2264476
#  -2.2443337  -2.2633753  -2.2854857  -2.3065655  -2.332188   -2.3568523
#  -2.3788774  -2.402605   -2.4266834  -2.4507668  -2.4759207  -2.5071094
#  -2.5349638  -2.5637016  -2.5915809  -2.6199915  -2.6450453  -2.6676073
#  -2.6897192  -2.7086537  -2.7245378  -2.7348735  -2.7391217  -2.737206
#  -2.7281954  -2.7084186  -2.6802347  -2.6392717  -2.586348   -2.5204206
#  -2.4404979  -2.3498547  -2.2423608  -2.1221225  -1.9899012  -1.8406687
#  -1.6777564  -1.5037963  -1.3162075  -1.1139097  -0.90671486 -0.6879216
#  -0.45744288 -0.21827896  0.03015444  0.28147992  0.54170334  0.8091701
#   1.078565    1.3461357   1.6160554   1.884465    2.1487582   2.411685
#   2.6716805   2.9306622   3.185789    3.4370167   3.6893551   3.9426925
#   4.186184    4.4221034   4.659977    4.889995    5.105903    5.3153396
#   5.518456    5.706548    5.8848996   6.0574274   6.2224693   6.383634
#   6.536842    6.678657    6.817602    6.95165     7.090239    7.237641
#   7.395372    7.5480204   7.6839895   7.808504    7.9300346   8.048154
#   8.16196     8.25642     8.326488    8.381668    8.429869    8.467125
#   8.483768    8.481941    8.464421    8.438185    8.400244    8.345987
#   8.2778225   8.199602    8.110097    8.011574    7.9028306   7.7768235
#   7.633436    7.478541    7.314822    7.13686     6.942841    6.735821
#   6.520831    6.296468    6.058798    5.813019    5.565003    5.3042593
#   5.030922    4.7534213   4.462682    4.1577067   3.844096    3.5220728
#   3.194093    2.8619378   2.5206642   2.1719732   1.815025    1.4541906
#   1.1031165   0.7715202   0.46572903  0.1707145  -0.11328951 -0.3833532
#  -0.63419044 -0.85515165 -1.0508457  -1.2369075  -1.4116089  -1.5724417
#  -1.7126815  -1.8325807  -1.9427322  -2.0448196  -2.1372526  -2.2162373
#  -2.2810218  -2.3378088  -2.389075   -2.4341173  -2.4705021  -2.4975379
#  -2.5187848  -2.5363338  -2.5498846  -2.5580606  -2.560268   -2.5586212
#  -2.554686   -2.54824    -2.5383966  -2.5250673  -2.5094051  -2.4921157
#  -2.4732199  -2.452525   -2.430026   -2.4061496  -2.3813412  -2.3557186
#  -2.3289998  -2.3014252  -2.2731287  -2.2441332  -2.2147996  -2.1853833
#  -2.1556277  -2.1253822  -2.0948875  -2.0643036  -2.0339985  -2.0038254
#  -1.9733508  -1.9427135  -1.9122932  -1.8824162  -1.8529252  -1.8233144
#  -1.7936631  -1.7643524  -1.7357601  -1.7077459  -1.6795468  -1.6512655
#  -1.6233951  -1.5963293  -1.5697759  -1.543189   -1.5167615  -1.4908954
#  -1.4657761  -1.4410288  -1.4162514  -1.3916913  -1.3676926  -1.3444661
#  -1.3215537  -1.2986962  -1.2761008  -1.2539308  -1.232436   -1.2113981
#  -1.190458   -1.169705   -1.1493505  -1.129757   -1.1104962  -1.091203
#  -1.0721719  -1.0536323  -1.0356525  -1.0180644  -1.0004969  -0.9830252
#  -0.9661115  -0.9497914  -0.9336539  -0.91763544 -0.90181744 -0.8864171
#  -0.87158006 -0.8569193  -0.84229505 -0.8278275  -0.81375456 -0.80014217
#  -0.7868036  -0.7735169  -0.7603705  -0.74758434 -0.7352625  -0.723123
#  -0.7109576  -0.6989856  -0.687345   -0.6761094  -0.6650285  -0.6539853
#  -0.6430496  -0.6324604  -0.62224245 -0.61215323 -0.6020803  -0.5921533
#  -0.5824961  -0.5732132  -0.56402874 -0.5548839  -0.5458232  -0.5370254
#  -0.52854127 -0.52012825 -0.5117674  -0.503518   -0.49552587 -0.48779503
#  -0.48013595 -0.47248292 -0.46494323 -0.45765167 -0.45059827 -0.4436257
#  -0.43664855 -0.42976913 -0.42310923 -0.41666418 -0.41027343 -0.40389076
#  -0.39758387 -0.39151534 -0.38563335 -0.3797804  -0.3739724  -0.3682157
#  -0.36262187 -0.3572256  -0.35187867 -0.34656426 -0.34128457 -0.33618346
#  -0.33128238 -0.32637456 -0.321466   -0.31666067 -0.31198633 -0.30745974
#  -0.30297324 -0.298482   -0.29405388 -0.28977484 -0.28563213 -0.28151017
#  -0.27740124 -0.27332446 -0.26938677 -0.26560435 -0.26181108 -0.2580182
#  -0.2543058  -0.25070143 -0.24719438 -0.24369928 -0.24023314 -0.23679835
#  -0.23346269 -0.2302508  -0.22704552 -0.22384414 -0.22069584 -0.21763493
#  -0.21466886 -0.21171404 -0.20876935 -0.20584624 -0.2030229  -0.20031033
#  -0.1975914  -0.19485782 -0.19216903 -0.18957715 -0.1870516  -0.18453242
#  -0.18203665 -0.17956792 -0.17715666 -0.17482093 -0.17250983 -0.17018965
#  -0.16789518 -0.16568188 -0.16353337]
# (array([ 34, 166]),)

# %%
z = np.linspace(
            afmulator.scan_window[0][2],
            afmulator.scan_window[1][2] - afmulator.df_steps * afmulator.dz,
            afmulator.scan_dim[2] - afmulator.df_steps + 1,
        )

x, y = 14, 32
#plt.plot(z, afm_images[14, 32, :])
plt.plot(z, afm_images[x, y, :])
plt.scatter(z[np.argmin(afm_images, axis=2)[x, y]], afm_images[x,y, np.argmin(afm_images, axis=2)[x, y]])

# %%
tst = afm_images[:,:,::-1]

# %%
plot_surface(tst[:,:,20])
plt.scatter(14, 32)

# %%
argmin_surface_and_blur("materials/pt_111_small.xyz")
# Out:
# Initializing an OpenCL environment on NVIDIA CUDA
# sigma:  0.7
# Spherical harmonic: s
# sigma:  0.7
# Spherical harmonic: s
#  plotting slice # 250
