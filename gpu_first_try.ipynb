# %%
from collections import defaultdict

from ppafm.io import loadXYZ
from ppafm.ocl.AFMulator import AFMulator
from ppafm.ocl.oclUtils import init_env

# %%
# Initialize an OpenCL environment. You can change i_platform to select the device to use.
init_env(i_platform=0)
# Out:
# Initializing an OpenCL environment on NVIDIA CUDA

# %%
# Load sample coordinates (xyzs), atomic numbers (Zs), and charges (qs)
xyzs, Zs, qs, _ = loadXYZ("materials/pt_111_small_1_3_vacancies.xyz")

# Create an instance of the simulator
# afmulator = AFMulator(
#     # scan_dim=(201, 201, 51),
#     # scan_window=((45.0, 25.0, 16), (60.0, 50.0, 19)),
#     df_steps=1,
#     # iZPP=8,
#     # tipR0=[0.0, 0.0, 3.0]
# )
afmulator = AFMulator.from_params("materials/params_code.ini")
# df_steps is calculated by dividing amplitude by scanStep in z dir
# afmulator.setScanWindow(df_steps=20)
# Out:
# sigma:  0.7
# Spherical harmonic: s

# %%
# Run the simulation and plot the resulting images
afm_images = afmulator(xyzs, Zs, qs, plot_to_dir="output")
# Out:
# sigma:  0.7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Run the simulation and plot the resulting images
# ----> 2 afm_images = afmulator(xyzs, Zs, qs, plot_to_dir="output")
#
# File ~/Documents/SharedDocuments/Uni/TU/InterdisciplinaryProject/repo/.venv_ip/lib/python3.12/site-packages/ppafm/ocl/AFMulator.py:168, in AFMulator.__call__(self, *args, **kwargs)
#     164 def __call__(self, *args, **kwargs):
#     165     """
#     166     Makes object callable. See :meth:`eval` for input arguments.
#     167     """
# --> 168     return self.eval(*args, **kwargs)
#
# File ~/Documents/SharedDocuments/Uni/TU/InterdisciplinaryProject/repo/.venv_ip/lib/python3.12/site-packages/ppafm/ocl/AFMulator.py:157, in AFMulator.eval(self, xyzs, Zs, qs, rho_sample, sample_lvec, rot, rot_center, REAs, X, plot_to_dir)
#     133 def eval(self, xyzs, Zs, qs, rho_sample=None, sample_lvec=None, rot=np.eye(3), rot_center=None, REAs=None, X=None, plot_to_dir=None):
#     134     """
#     135     Prepare and evaluate AFM image.
#     136
#    (...)
#     155         X: np.ndarray. Output AFM images. If input X is not None, this is the same array object as X with values overwritten.
#     156     """
# --> 157     self.prepareFF(xyzs, Zs, qs, rho_sample, sample_lvec, rot, rot_center, REAs)
#     158     self.prepareScanner()
#     159     X = self.evalAFM(X)
#
# File ~/Documents/SharedDocuments/Uni/TU/InterdisciplinaryProject/repo/.venv_ip/lib/python3.12/site-packages/ppafm/ocl/AFMulator.py:327, in AFMulator.prepareFF(self, xyzs, Zs, qs, rho_sample, sample_lvec, rot, rot_center, REAs)
#     324 self.forcefield.tryReleaseBuffers()
#     325 if self._rho is not None:
#     326     # The grid size changed so we need to recompute/reinterpolate the tip density grid
# --> 327     self.setRho(self._rho, self.sigma, self.B_pauli)
#     328     self.setRhoDelta(self.rho_delta)  # self.rho_delta could be None, but then this does nothing
#     329 self.forcefield.prepareBuffers()
#
# File ~/Documents/SharedDocuments/Uni/TU/InterdisciplinaryProject/repo/.venv_ip/lib/python3.12/site-packages/ppafm/ocl/AFMulator.py:237, in AFMulator.setRho(self, rho, sigma, B_pauli)
#     235 self._rho = rho  # Remember argument value so that we can recompute the power from grid or the grid from a dict later if needed
#     236 if isinstance(rho, dict):
# --> 237     self.rho = MultipoleTipDensity(
#     238         self.forcefield.lvec[:, :3],
#     239         self.forcefield.nDim[:3],
#     240         sigma=self.sigma,
#     241         multipole=rho,
#     242         ctx=self.forcefield.ctx,
#     243     )
#     244 else:
#     245     if not isinstance(rho, TipDensity):
#
# File ~/Documents/SharedDocuments/Uni/TU/InterdisciplinaryProject/repo/.venv_ip/lib/python3.12/site-packages/ppafm/ocl/field.py:591, in MultipoleTipDensity.__init__(self, lvec, shape, center, sigma, multipole, tilt, ctx)
#     590 def __init__(self, lvec, shape, center=[0, 0, 0], sigma=0.71, multipole={"dz2": -0.1}, tilt=0.0, ctx=None):
# --> 591     array = self._make_tip_density(lvec, shape, center, sigma, multipole, tilt)
#     592     lvec = np.concatenate([[[0, 0, 0]], lvec], axis=0)
#     593     super().__init__(array, lvec, ctx)
#
# File ~/Documents/SharedDocuments/Uni/TU/InterdisciplinaryProject/repo/.venv_ip/lib/python3.12/site-packages/ppafm/ocl/field.py:612, in MultipoleTipDensity._make_tip_density(self, lvec, shape, center, sigma, multipole, tilt)
#     610 X, Y, Z = np.meshgrid(*xyz, indexing="ij")
#     611 step = lvec_len / shape
# --> 612 rho = getProbeDensity(lvec, X, Y, Z, step, sigma=sigma, multipole_dict=multipole, tilt=tilt)
#     614 if bRuntime:
#     615     print("runtime(MultipoleTipDensity._make_tip_density) [s]: ", time.perf_counter() - t0)
#
# File ~/Documents/SharedDocuments/Uni/TU/InterdisciplinaryProject/repo/.venv_ip/lib/python3.12/site-packages/ppafm/fieldFFT.py:121, in getProbeDensity(sampleSize, X, Y, Z, dd, sigma, multipole_dict, tilt)
#     118 rz = X * mat[2, 0] + Y * mat[2, 1] + Z * mat[2, 2]
#     119 rquad = rx**2 + ry**2 + rz**2
# --> 121 radial = np.exp(-(rquad) / (2 * sigma**2))
#     122 radial_renom = np.sum(radial) * np.abs(np.linalg.det(mat)) * dd[0] * dd[1] * dd[2]  # TODO analytical renormalization may save some time ?
#     123 radial /= radial_renom
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] =  [10, 10]

def plot_surface(img, vmin=None, vmax=None):
    plt.imshow(img[:,::-1].T, vmin=vmin, vmax=vmax)
    
plot_surface(afm_images[:,:,188])
plt.scatter(14, 32)

# %%
import numpy as np
z = np.linspace(
            afmulator.scan_window[0][2],
            afmulator.scan_window[1][2] - afmulator.df_steps * afmulator.dz,
            afmulator.scan_dim[2] - afmulator.df_steps + 1,
        )

# %%
x, y = 14, 32
#plt.plot(z, afm_images[14, 32, :])
plt.plot(z, afm_images[x, y, :])
plt.scatter(z[np.argmin(afm_images, axis=2)[x, y]], afm_images[x,y, np.argmin(afm_images, axis=2)[x, y]])

#plt.xlim(18.5, 19.5)
#plt.ylim(-3.3, -2)

# %%
from scipy.ndimage import gaussian_filter

plt.rcParams["figure.figsize"] =  [20, 10]

min_image = np.argmin(afm_images, axis=2)
blurred_image = gaussian_filter(min_image, sigma=6)
vmin = np.min(min_image)
vmax = np.max(min_image)

plt.subplots(1, 2)

plt.subplot(1, 2, 1)
plt.title(f"Unique indices: {np.unique(min_image)}")
plot_surface(min_image, vmin=vmin, vmax=vmax)
plt.scatter(21, 32)

plt.subplot(1, 2, 2)
plt.title(f"Unique indices: {np.unique(blurred_image)}")
plot_surface(blurred_image, vmin=vmin, vmax=vmax)

# %%
x, y = 21, 32
print(np.median(np.argmin(afm_images, axis=2)))
print(afm_images[x, y, 188])
print(np.argmin(afm_images, axis=2)[x, y])
z[np.argmin(afm_images, axis=2)[x, y]]

# %%
unique_vals = np.unique(np.argmin(afm_images, axis=2))
print(z[unique_vals[0]], z[unique_vals[-1]])

# %% [markdown]
# # New functions

# %%
from ppafm.io import loadXYZ
from ppafm.ocl.AFMulator import AFMulator
from ppafm.ocl.oclUtils import init_env
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from scipy.signal import argrelextrema
import numpy as np
from collections import defaultdict

def plot_surface(img, vmin=None, vmax=None):
    plt.imshow(img.T, vmin=vmin, vmax=vmax)
    
def compute_imgs(path_surface):
    init_env(i_platform=0)
    xyzs, Zs, qs, _ = loadXYZ(path_surface)
    afmulator = AFMulator.from_params("materials/params_code.ini")
    afm_images = afmulator(xyzs, Zs, qs)#, plot_to_dir="output")
    
    return afmulator, afm_images
    
    
def argmin_surface_and_blur(afmulator, afm_images, xy=(32, 14), sigma=3):
    # if compute_img:
    # init_env(i_platform=0)
    # xyzs, Zs, qs, _ = loadXYZ(path_surface)
    # afmulator = AFMulator.from_params("materials/params_code.ini")
    # afm_images = afmulator(xyzs, Zs, qs, plot_to_dir="output")[:,:,::-1]
    
    plt.rcParams["figure.figsize"] =  [20, 10]
    
    afm_images_transformed = afm_images[:,::-1,::-1]
    
    minima = np.array(argrelextrema(afm_images_transformed, np.less_equal, axis=2)).T
    minima_dict = defaultdict(list)
    for x, y, z in minima:
        minima_dict[x, y].append(z)
        minima_dict[x, y] = [max(minima_dict[x, y])]
    
    argmin_image = np.zeros(afm_images_transformed.shape[0:-1], dtype=int)
    for pixel, val in minima_dict.items():
        argmin_image[pixel] = int(val[0])
    
    xy = np.array(xy)
    
    z = np.linspace(
                afmulator.scan_window[0][2],
                afmulator.scan_window[1][2] - afmulator.df_steps * afmulator.dz,
                afmulator.scan_dim[2] - afmulator.df_steps + 1,
    )
    
    min_image = z[argmin_image]
    #min_image = z[np.argmin(afm_images_transformed, axis=2)]
    blurred_image = gaussian_filter(min_image, sigma=sigma)
    vmin = np.min(min_image)
    vmax = np.max(min_image)
    
    plt.subplots(1, 2)
    
    plt.subplot(1, 2, 1)
    #plt.title(f"Unique indices: {np.unique(min_image)}")
    plt.title("Minimas of each Pixel")
    plot_surface(min_image, vmin=vmin, vmax=vmax)
    plt.colorbar()
    plt.scatter(xy[0], xy[1], color='red')
    plt.tight_layout()
    plt.axvline(xy[0], color='orange')
    plt.axhline(xy[1], color='magenta')
    
    plt.subplot(1, 2, 2)
    #plt.title(f"Unique indices: {np.unique(blurred_image)}")
    plt.title(f"Blurred version {sigma=}")
    plot_surface(blurred_image, vmin=vmin, vmax=vmax)
    plt.colorbar()
    plt.scatter(xy[0], xy[1], color='red')
    plt.tight_layout()
    plt.axvline(xy[0], color='orange')
    plt.axhline(xy[1], color='magenta')
    
    plt.show()
    
    minima = argrelextrema(afm_images_transformed[xy[0], xy[1]], np.less_equal)#[xy[0], xy[1]]
    #print(minima[0])
    
    plt.title(f"df curve for pixel {xy}")
    plt.xlabel("Distance / (Å)")
    plt.ylabel("df / (Hz)")
    plt.plot(z, afm_images_transformed[xy[0], xy[1], :])
    #plt.scatter(z[np.argmin(afm_images_transformed, axis=2)[xy[0], xy[1]]], afm_images_transformed[xy[0],xy[1], np.argmin(afm_images_transformed, axis=2)[xy[0], xy[1]]])
    for minimum in minima:
        plt.scatter(z[minimum], afm_images_transformed[xy[0], xy[1], minimum], color="red")
        
    plt.show()
    
    plt.title("Slice in x direction")
    plt.plot(gaussian_filter(min_image[:,xy[1]], sigma=sigma))
    plt.plot(min_image[:,xy[1]], color="magenta")
    plt.ylabel("Height / (Å)")
    plt.show()
    
    plt.title("Slice in y direction")
    plt.plot(gaussian_filter(min_image[xy[0],:], sigma=sigma))
    plt.plot(min_image[xy[0], :], color="orange")
    plt.ylabel("Height / (Å)")
    plt.show()
    
    return min_image, blurred_image, z
# Out:
#  PACKAGE_PATH =  /home/henry/Documents/SharedDocuments/Uni/TU/InterdisciplinaryProject/repo/.venv_ip/lib/python3.12/site-packages/ppafm
#  CPP_PATH     =  /home/henry/Documents/SharedDocuments/Uni/TU/InterdisciplinaryProject/repo/.venv_ip/lib/python3.12/site-packages/ppafm/cpp

# %%
afmulator, afm_images = compute_imgs("materials/pt_111_small_single_adatom.xyz")
# Out:
# Initializing an OpenCL environment on NVIDIA CUDA
# sigma:  0.7
# Spherical harmonic: s
# sigma:  0.7
# Spherical harmonic: s

# %%
# pt_111_smal_1_3_vacancies.xyz
xy_3_vacancy = (118, 69)
xy_1_vacancy = (21, 20)

# pt_111_small_rows_missing.xyz
xy_2row_corner = (103, 67)
xy_3row_corner = (146, 67)
xy_3row_middle = (171, 44)
xy_reference = (77, 67)

#pt_111_small_single_adatom
xy_adatom = (27, 32)

xy_test = (162, 44)
#xy_test = (200, 200)

min_image, blurred_image, z = argmin_surface_and_blur(afmulator, afm_images, xy=xy_adatom, sigma=4)

# %%
plt.plot(min_image[:,44])
plt.plot(gaussian_filter(min_image[:,44]+0.4, sigma=4))
#plt.plot(gaussian_filter(min_image[:,162], sigma=6))
plt.show()
gaussian_filter(min_image[171,:], sigma=4)
# Out:
# array([13.99064452, 13.99111875, 13.99224089, 13.99432522, 13.99780799,
#        14.00324144, 14.01134345, 14.02311474, 14.04001759, 14.06416931,
#        14.09845665, 14.14646407, 14.21211789, 14.29902067, 14.40957401,
#        14.54411011, 14.70032036, 14.87321725, 15.05572669, 15.23977351,
#        15.41756237, 15.58269494, 15.73084286, 15.85987942, 15.96955401,
#        16.0609093 , 16.1356542 , 16.19565179, 16.24259161, 16.27783095,
#        16.30236304, 16.31681047, 16.321539  , 16.31662568, 16.30186017,
#        16.2767358 , 16.24035348, 16.19135068, 16.12787516, 16.0476664 ,
#        15.94832837, 15.82783923, 15.6852745 , 15.52159763, 15.34027617,
#        15.14744225, 14.95141265, 14.7615778 , 14.58690671, 14.43448878,
#        14.30853081, 14.21005555, 14.13730914, 14.0866349 , 14.05348546,
#        14.03328484, 14.02198327, 14.01629664, 14.0137271 , 14.01247349,
#        14.01131978, 14.00954251, 14.00683462, 14.0032276 , 13.99901264,
#        13.99457575, 13.99035625, 13.98670212, 13.98381049, 13.9817099 ,
#        13.98029576, 13.97939912, 13.97886849, 13.97863412, 13.97873805,
#        13.9793142 , 13.98053258, 13.9825204 , 13.98529259, 13.98870809,
#        13.99247248, 13.99618485, 13.99941295, 14.00177941, 14.00303833,
#        14.00311896, 14.00213511, 14.00035576, 13.99814478, 13.99588461,
#        13.99390149, 13.99240606, 13.99146829, 13.99102528, 13.9909261 ,
#        13.99099675, 13.99110634, 13.99121809, 13.99140613, 13.99183226,
#        13.99269298, 13.99414691, 13.99624912, 13.99890778, 14.00188088,
#        14.00481089, 14.00729324, 14.00895648, 14.00954186, 14.00895648,
#        14.00729324, 14.00481089, 14.00188088, 13.99890844, 13.99625088,
#        13.99415128, 13.99270379, 13.99185619, 13.99145597, 13.99131588,
#        13.9912872 , 13.99131218, 13.99144582, 13.99183336, 13.99265589,
#        13.9940575 , 13.996077  , 13.99860441, 14.00137749, 14.00402002,
#        14.00611078, 14.00727068, 14.00724207, 14.0059458 , 14.00350002,
#        14.00019979, 13.99645991, 13.9927315 , 13.98941445, 13.98677986,
#        13.9849272 , 13.9837841 , 13.98315495, 13.98280105, 13.9825329 ,
#        13.98228015, 13.98212159, 13.98225796, 13.98293969, 13.98437288,
#        13.98663551, 13.98962499, 13.99306259, 13.99654246, 13.99961713,
#        14.00188922, 14.00309394, 14.00314548, 14.00214702, 14.00036079,
#        13.99814654, 13.99588461, 13.99389973, 13.9924017 , 13.99145814,
#        13.99100312, 13.99088063, 13.99090844, 13.99094587, 13.99094376,
#        13.99096458, 13.99116182, 13.99173247, 13.99284501, 13.99457386,
#        13.9968535 , 13.99946624, 14.0020707 , 14.00426502, 14.005669  ,
#        14.00600697, 14.00516974, 14.00324115, 14.00048173, 13.99727508,
#        13.99404505, 13.99117007, 13.98891258, 13.98737923, 13.98652153,
#        13.98617596, 13.98612624, 13.98617049, 13.98616973, 13.98606963,
#        13.9858865 , 13.98567662, 13.98549593, 13.98537502, 13.9853131 ,
#        13.98529073])

# %%
z = np.linspace(
            afmulator.scan_window[0][2],
            afmulator.scan_window[1][2] - afmulator.df_steps * afmulator.dz,
            afmulator.scan_dim[2] - afmulator.df_steps + 1,
        )

x, y = 14, 32
#plt.plot(z, afm_images[14, 32, :])
plt.plot(z, afm_images[x, y, :])
plt.scatter(z[np.argmin(afm_images, axis=2)[x, y]], afm_images[x,y, np.argmin(afm_images, axis=2)[x, y]])

# %%
tst = afm_images[:,:,::-1]

# %%
plot_surface(tst[:,:,20])
plt.scatter(14, 32)

# %%
argmin_surface_and_blur("materials/pt_111_small.xyz")
